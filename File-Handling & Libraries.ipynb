# %%
college = {
    "CSE": {
        "Ravi": {
            "Maths": 85,
            "Python": 90
        },
        "Anil": {
            "Maths": 78,
            "Python": 88
        }
    },

    "ECE": {
        "Sita": {
            "Maths": 80,
            "Python": 85
        }
    }
}

# %%
print(college)
# Out:
# {'CSE': {'Ravi': {'Maths': 85, 'Python': 90}, 'Anil': {'Maths': 78, 'Python': 88}}, 'ECE': {'Sita': {'Maths': 80, 'Python': 85}}}

# %%
import json

with open("data.json", "w") as file:
  json.dump(college, file)

# %%
print(college)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3790871158.py in <cell line: 0>()
# ----> 1 print(college)
#
# NameError: name 'college' is not defined

# %%
import json

with open("data.json" , "r") as file:
  college = json.load(file)

# %%
print(college)
# Out:
# {'CSE': {'Ravi': {'Maths': 85, 'Python': 90}, 'Anil': {'Maths': 78, 'Python': 88}}, 'ECE': {'Sita': {'Maths': 80, 'Python': 85}}}

# %%
students = {
    "S1": {
        "name": "Rahul",
        "age": 21,
        "marks": {
            "math": 78,
            "science": 85,
            "english": 74
        }
    },
    "S2": {
        "name": "Anita",
        "age": 22,
        "marks": {
            "math": 92,
            "science": 88,
            "english": 90
        }
    },
    "S3": {
        "name": "Kiran",
        "age": 20,
        "marks": {
            "math": 65,
            "science": 70,
            "english": 68
        }
    }
}

# %%
import json

with open("student-data.json" , "w") as file:
  json.dump(students, file)

# %%
import json

with open("student-data.json", "r") as file:
  students = json.load(file)

# %%
messages = [
    "AI : how are you",
    "Me : I am fine",
    "AI : How was the day",
    "Me : It's very good and fine"
]


with open("conversation.txt" , "w") as file:
  for message in messages:
    file.write(message + "\n")

print("conversatin saved")
# Out:
# conversatin saved

# %%
import json

with open("conversation.txt" , "r") as file:
  load_data = file.read()
  print(load_data)
# Out:
# AI : how are you
# Me : I am fine
# AI : How was the day
# Me : It's very good and fine

# %%
students = {
    "S1": {
        "name": "Rahul",
        "age": 21,
        "marks": {
            "math": 78,
            "science": 85,
            "english": 74
        }
    },
    "S2": {
        "name": "Anita",
        "age": 22,
        "marks": {
            "math": 92,
            "science": 88,
            "english": 90
        }
    },
    "S3": {
        "name": "Kiran",
        "age": 20,
        "marks": {
            "math": 65,
            "science": 70,
            "english": 68
        }
    }
}

# %% [markdown]
# #Pretty printing the JSON - Format

# %%
import json

with open("students.json" , "w") as file:
  json.dump(students , file , indent = 3)

# %% [markdown]
# #File handling using Function Methods

# %%
import json

def save_config(file_config , config):
  with open(file_config, "w") as file:
    json.dump(config , file, indent=2)

def load_config(file_config):
  with open(file_config , "r") as file:
    temp_load = json.load(file)
    return temp_load

# %%
college_data = {
    "CSE": {
        "Ravi": {
            "Maths": 85,
            "Python": 90
        },
        "Anil": {
            "Maths": 78,
            "Python": 88
        }
    },

    "ECE": {
        "Sita": {
            "Maths": 80,
            "Python": 85
        }
    }
}

# %%
students = {
    "S1": {
        "name": "Rahul",
        "age": 21,
        "marks": {
            "math": 78,
            "science": 85,
            "english": 74
        }
    },
    "S2": {
        "name": "Anita",
        "age": 22,
        "marks": {
            "math": 92,
            "science": 88,
            "english": 90
        }
    },
    "S3": {
        "name": "Kiran",
        "age": 20,
        "marks": {
            "math": 65,
            "science": 70,
            "english": 68
        }
    }
}

# %%
save_config("/content/Temporary_folder/college_data.json" , college_data)
save_config("/content/Temporary_folder/Students_data.json", students)

# %%
print_config =  load_config("/content/Temporary_folder/college_data.json")
print(print_config)

print_config2 = load_config("/content/Temporary_folder/Students_data.json")
print(print_config2)
# Out:
# {'CSE': {'Ravi': {'Maths': 85, 'Python': 90}, 'Anil': {'Maths': 78, 'Python': 88}}, 'ECE': {'Sita': {'Maths': 80, 'Python': 85}}}
# {'S1': {'name': 'Rahul', 'age': 21, 'marks': {'math': 78, 'science': 85, 'english': 74}}, 'S2': {'name': 'Anita', 'age': 22, 'marks': {'math': 92, 'science': 88, 'english': 90}}, 'S3': {'name': 'Kiran', 'age': 20, 'marks': {'math': 65, 'science': 70, 'english': 68}}}

# %%
def save_data(file_name , data_name):
  with open(file_name, "w") as file:
    json.dump(data_name , file , indent = 4)

def read_data(file_name):
  with open(file_name , "r") as file:
    json_data = json.load(file)
    return json_data

# %%
student_data = {
    "S1": {
        "name": "Rahul",
        "age": 21,
        "marks": {
            "math": 78,
            "science": 85,
            "english": 74
        }
    },
    "S2": {
        "name": "Anita",
        "age": 22,
        "marks": {
            "math": 92,
            "science": 88,
            "english": 90
        }
    },
    "S3": {
        "name": "Kiran",
        "age": 20,
        "marks": {
            "math": 65,
            "science": 70,
            "english": 68
        }
    }
}

# %%
save_data("/content/Data_folder/students.json" , student_data)

# %%
loading_data = read_data("/content/Data_folder/students.json")
print(loading_data)
# Out:
# {'S1': {'name': 'Rahul', 'age': 21, 'marks': {'math': 78, 'science': 85, 'english': 74}}, 'S2': {'name': 'Anita', 'age': 22, 'marks': {'math': 92, 'science': 88, 'english': 90}}, 'S3': {'name': 'Kiran', 'age': 20, 'marks': {'math': 65, 'science': 70, 'english': 68}}}
